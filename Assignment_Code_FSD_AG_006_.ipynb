# %% [markdown]
# #JavaScript - Array Methods & More | Assignment

# %% [markdown]
# ##Question 1 : Explain what the forEach method does in JavaScript arrays and write code that uses forEach to display each student's name from an array of student objects to the console. // Array of student objects
# const students = [
# { name: "Rahul", age: 20 },
# { name: "Priya", age: 19 },
# { name: "Amit", age: 21 },
# { name: "Sneha", age: 20 }
# ];

# %%
# %%javascript
# // Array of student objects
# const students = [
#   { name: "Rahul", age: 20 },
#   { name: "Priya", age: 19 },
#   { name: "Amit", age: 21 },
#   { name: "Sneha", age: 20 }
# ];
#
# // Using forEach to display each student's name
# students.forEach((student) => {
#   console.log(student.name);
# });

# %% [markdown]
# ##Question 2 : You have an array of product prices in rupees. Write code using the map method to create a new array that contains the same prices but with 18% GST added to each price.
# const originalPrices = [100, 250, 500, 750, 1000];

# %%
# %%javascript
# const originalPrices = [100, 250, 500, 750, 1000];
#
# const pricesWithGST = originalPrices.map(price => (price * 1.18).toFixed(2));
#
# console.log(pricesWithGST);

# %% [markdown]
# ##Question 3 : A school wants to find all students who scored more than 80 marks in their exam. The following code has an error that prevents it from working correctly. Fix the code and explain what was wrong.
# const students = [
# { name: "Raj", marks: 85 },
# { name: "Sita", marks: 92 },
# { name: "Vikram", marks: 78 },
# { name: "Meera", marks: 88 }
# ];
# const topStudents = students.filter(student => {
# student.marks > 80;
# });

# %%
# %%javascript
# const students = [
#   { name: "Raj", marks: 85 },
#   { name: "Sita", marks: 92 },
#   { name: "Vikram", marks: 78 },
#   { name: "Meera", marks: 88 }
# ];
#
# const topStudents = students.filter(student => {
#   return student.marks > 80
#   });
#
# console.log(topStudents);

# %% [markdown]
# ##Question 4 : Write code using the find method to locate a book with the title "Harry Potter" from an array of book objects. If the book is found, display its author name, otherwise display "Book not found". // Array of book objects
# const books = [
# { title: "Gitanjali", author: "Rabindranath Tagore" },
# { title: "Harry Potter", author: "J.K. Rowling" },
# { title: "The God of Small Things", author: "Arundhati Roy" },
# { title: "Midnight's Children", author: "Salman Rushdie" }
# ];

# %%
# %%javascript
# // Array of book objects
# const books = [
#   { title: "Gitanjali", author: "Rabindranath Tagore" },
#   { title: "Harry Potter", author: "J.K. Rowling" },
#   { title: "The God of Small Things", author: "Arundhati Roy" },
#   { title: "Midnight's Children", author: "Salman Rushdie" }
# ];
#
# // Find the book with title "Harry Potter"
# const book = books.find(b => b.title === "Harry Potter");
#
# // Check if found and display result
# if (book) {
#   console.log("Author:", book.author);
# } else {
#   console.log("Book not found");
# }

# %% [markdown]
# ##Question 5 : Explain how the sort method works in JavaScript and write code to sort an array of employee objects by their salary in descending order (highest salary first). // Array of employee objects
# const employees = [
# { name: "Rajesh", salary: 45000 },
# { name: "Priya", salary: 55000 },
# { name: "Amit", salary: 40000 },
# { name: "Kavya", salary: 60000 }
# ];
# - You tell JavaScript how to compare two items, and it rearranges the array based on that rule.
# Important point: sort changes the original array.
# - **(a, b) => a - b**
# - If result is negative → a comes before b
#
# - If result is positive → b comes before a
#
# - If result is 0 → no change
#
# - **For descending order (highest salary first), we subtract the other way:**
# - b.salary - a.salary

# %%
# %%javascript
# // Array of employee objects
# const employees = [
#   { name: "Rajesh", salary: 45000 },
#   { name: "Priya", salary: 55000 },
#   { name: "Amit", salary: 40000 },
#   { name: "Kavya", salary: 60000 }
# ];
#
# // Sort by salary in descending order
# employees.sort((a, b) => b.salary - a.salary);
#
# console.log(employees);

# %% [markdown]
# ##Question 6 : Write code using the reduce method to calculate the total value of all items in a shopping cart. Each item has a price and quantity. Also find the most expensive single item in the cart. // Shopping cart with items
# const cart = [
# { name: "Laptop", price: 50000, quantity: 1 },
# { name: "Mouse", price: 500, quantity: 2 },
# { name: "Keyboard", price: 1500, quantity: 1 },
# { name: "Monitor", price: 15000, quantity: 1 }
# ];

# %%
# %%javascript
# // Shopping cart with items
# const cart = [
#   { name: "Laptop", price: 50000, quantity: 1 },
#   { name: "Mouse", price: 500, quantity: 2 },
#   { name: "Keyboard", price: 1500, quantity: 1 },
#   { name: "Monitor", price: 15000, quantity: 1 }
# ];
#
# // 1. Total value of cart (price × quantity)
# const totalValue = cart.reduce((total, item) => {
#   return total + (item.price * item.quantity);
# }, 0);
#
# console.log("Total Cart Value:", totalValue);
#
# // 2. Most expensive single item (based on price)
# const mostExpensiveItem = cart.reduce((maxItem, currentItem) => {
#   return currentItem.price > maxItem.price ? currentItem : maxItem;
# });
#
# console.log("Most Expensive Item:", mostExpensiveItem);

# %% [markdown]
# ##Question 7 : Explain what array destructuring is and write code that extracts the first two colors from an array of colors into separate variables using destructuring. // Array of colors
# const colors = ["red", "blue", "green", "yellow", "purple"];
# - Array destructuring is a shortcut way to take values out of an array and store them into separate variables in a single line.
# Instead of picking items by index one by one, you “unpack” the array like opening a gift box and pulling items directly into named variables.

# %%
# %%javascript
# // Array of colors
# const colors = ["red", "blue", "green", "yellow", "purple"];
#
# // Destructuring to extract first two colors
# const [firstColor, secondColor] = colors;
#
# console.log("First Color:", firstColor);
# console.log("Second Color:", secondColor);

# %% [markdown]
# ##Question 8 : You have a student object with name, age, and marks properties. Write code using object destructuring to extract these values into separate variables and also rename the marks property to score while destructuring. // Student object
# const student = {
# name: "Arjun",
# age: 20,
# marks: 85,
# city: "Mumbai"
# };
# - Object destructuring lets you take properties from an object and store them into variables in one clean move.
# You can even rename a property while extracting it. It’s like opening a suitcase and labeling each item as you place it on the shelf.

# %%
# %%javascript
# // Student object
# const student = {
#   name: "Arjun",
#   age: 20,
#   marks: 85,
#   city: "Mumbai"
# };
#
# // Object destructuring with renaming (marks → score)
# const { name, age, marks: score } = student;
#
# console.log("Name:", name);
# console.log("Age:", age);
# console.log("Score:", score);

# %% [markdown]
# ##Question 9 : Write a function called calculateTotal that can accept any number of prices as arguments and returns their sum. Use the rest operator to handle the variable number of parameters.
# - The rest operator (...) is like a magic basket.
# Whatever extra arguments you pass, it gathers them into an array so you can work with them easily.
# - Function requirement:
# - Accept any number of prices
# - Add them all
# - Return the total

# %%
# %%javascript
# function calculateTotal(...prices) {
#   return prices.reduce((sum, price) => sum + price, 0);
# }
#
# // Testing the function
# console.log(calculateTotal(100, 200, 300));        // 600
# console.log(calculateTotal(50, 75, 125, 250));     // 500
# console.log(calculateTotal(1000));                 // 1000

# %% [markdown]
# ##Question 10 : You have two arrays of student names and need to create a new array that contains all students from both arrays. Also, you have two objects representing a student's basic info and marks. Write code using the spread operator to solve both scenarios.
# const classA = ["Rahul", "Priya", "Amit"];
# const classB = ["Sneha", "Vikram", "Pooja"];
# - The spread operator (...) is like opening a box and pouring everything inside into another container.
# It “spreads” the elements of an array or properties of an object.

# %%
# %%javascript
# // Arrays of students
# const classA = ["Rahul", "Priya", "Amit"];
# const classB = ["Sneha", "Vikram", "Pooja"];
#
# // 1. Combine both arrays using spread operator
# const allStudents = [...classA, ...classB];
# console.log("All Students:", allStudents);
#
# // Objects representing student info
# const studentInfo = {
#   name: "Piyush",
#   age: 20
# };
#
# const studentMarks = {
#   marks: 85,
#   grade: "A"
# };
#
# // 2. Combine both objects using spread operator
# const studentDetails = { ...studentInfo, ...studentMarks };
# console.log("Student Details:", studentDetails);
